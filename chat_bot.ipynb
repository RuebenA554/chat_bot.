# %%
# !pip install bardapi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 54.2 MB/s eta 0:00:00
# ...

# %%
from bardapi import Bard
import os
import time

# %%
os.environ['__BARD_API_KEY'] = "g.a000owgCHC4tFidq96AjCfnjNdXYTvCPXUXD9h8VzzT4-kwmkxCfUWiKjcutOhgqUaQf1UGN_gACgYKAQkSARYSFQHGX2MiX-BtZz7QK1rAGzkswuamDhoVAUF8yKqwPf7I7Bav30H9SkzDIiQR0076"

# %%
input_text = "why is the sky blue?"
print(Bard().get_answer(input_text)['content'])
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-20-d9c0457965b5> in <cell line: 2>()
#       1 input_text = "why is the sky blue?"
# ----> 2 print(Bard().get_answer(input_text)['content'])
#
# /usr/local/lib/python3.10/dist-packages/bardapi/core.py in __init__(self, token, timeout, proxies, session, conversation_id, google_translator_api_key, language, run_code, token_from_browser, multi_cookies_bool, cookie_dict)
#      74         self.cookie_dict = cookie_dict
#      75         self.multi_cookies_bool = multi_cookies_bool
# ---> 76         self.token = self._get_token(token, token_from_browser, multi_cookies_bool)
#      77         self.proxies = proxies
#      78         self.timeout = timeout
#
# /usr/local/lib/python3.10/dist-packages/bardapi/core.py in _get_token(self, token, token_from_browser, multi_cookies_bool)
# ...
